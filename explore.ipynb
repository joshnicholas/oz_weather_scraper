# %%
import pandas as pd
from sudulunu.helpers import pp, dumper
import json

# %%
df = pd.read_json('new_data/observations/Melbourne.json')

# ['time', 'temperature_2m', 'apparent_temperature', 'dew_point_2m', 
# 'relative_humidity_2m', 'precipitation', 'rain', 'snowfall', 'cloud_cover', 
# 'pressure_msl', 'surface_pressure', 'wind_speed_10m', 'wind_direction_10m', 
# 'wind_gusts_10m', 'visibility', 'uv_index', 'sunshine_duration', 'city']

# pp(df)
print(df[['time', 'relative_humidity_2m']].tail(20))
# Out:
#                          time  relative_humidity_2m
# 4   2026-02-13 04:00:00+00:00             54.431557
# 5   2026-02-13 05:00:00+00:00             55.351601
# 6   2026-02-13 06:00:00+00:00             52.111820
# 7   2026-02-13 07:00:00+00:00             57.337486
# 8   2026-02-13 08:00:00+00:00             59.511360
# 9   2026-02-13 09:00:00+00:00             64.695389
# 10  2026-02-13 10:00:00+00:00             68.741943
# 11  2026-02-13 11:00:00+00:00             71.209267
# 12  2026-02-13 12:00:00+00:00             74.540222
# 13  2026-02-13 13:00:00+00:00             77.745628
# 14  2026-02-13 14:00:00+00:00             81.643784
# 15  2026-02-13 15:00:00+00:00             83.814369
# 16  2026-02-13 16:00:00+00:00             85.187958
# 17  2026-02-13 17:00:00+00:00             85.187958
# 18  2026-02-13 18:00:00+00:00             84.358688
# 19  2026-02-13 19:00:00+00:00             85.166565
# 20  2026-02-13 20:00:00+00:00             87.677383
# ...

# %%
# df = pd.read_json('new_data/forecasts/Melbourne.json')

with open('new_data/forecasts/Melbourne.json', 'r') as f:
    jsony = json.loads(f.read())

print(jsony.keys())
# dict_keys(['hourly', 'daily'])

print(jsony['hourly'][0].keys())
# dict_keys(['time', 'temperature_2m', 'apparent_temperature', 
# 'dew_point_2m', 'relative_humidity_2m', 'precipitation', 'rain', 'snowfall', 
# 'cloud_cover', 'pressure_msl', 'surface_pressure', 'wind_speed_10m', 'wind_direction_10m', 
# 'wind_gusts_10m', 'visibility', 'uv_index', 'sunshine_duration', 'city'])

print(jsony['hourly'][0]['uv_index'])

# df = pd.read_csv(jsony)


# pp(df)
# Out:
# dict_keys(['hourly', 'daily'])
# dict_keys(['time', 'temperature_2m', 'apparent_temperature', 'dew_point_2m', 'relative_humidity_2m', 'precipitation', 'rain', 'snowfall', 'cloud_cover', 'pressure_msl', 'surface_pressure', 'wind_speed_10m', 'wind_direction_10m', 'wind_gusts_10m', 'visibility', 'uv_index', 'sunshine_duration', 'city'])
# 4.8499999046
